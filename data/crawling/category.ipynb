# %%
import pickle
import requests

# %%
import pickle

category = [
    {
        "category_name": "여성의류",
        "category_code": 268100100,
        'gender': 'female',
        "category2": [
            {
                "category_name": "상의",
                "category_code": 268103100,
                "category3": [
                    {"category_name": "반소매 티셔츠", "category_code": 268103101,"num1": 1, "num2": 2},
                    {"category_name": "긴소매 티셔츠", "category_code": 268103102,"num1": 1, "num2": 1},
                    {"category_name": "슬리브리스", "category_code": 268103103,"num1": 1, "num2": 3},
                    {"category_name": "스웨트셔츠", "category_code": 268103104,"num1": 1, "num2": 6},
                    {"category_name": "후디", "category_code": 268103105,"num1": 1, "num2": 4},
                    {"category_name": "셔츠", "category_code": 268103106,"num1": 1, "num2": 7},
                    {"category_name": "블라우스", "category_code": 268103107,"num1": 1, "num2": 7}
                ]
            },
            {
                "category_name": "바지",
                "category_code": 268106100,
                "category3": [
                    {"category_name": "부츠컷", "category_code": 268106110, "num1": 2, "num2": 0},
                    {"category_name": "쇼트", "category_code": 268106108, "num1": 2, "num2": 0},
                    {"category_name": "슬림", "category_code": 268106103, "num1": 2, "num2": 0},
                    {"category_name": "스트레이트", "category_code": 268106101, "num1": 2, "num2": 0},
                    {"category_name": "와이드", "category_code": 268106102, "num1": 2, "num2": 0},
                    {"category_name": "데님", "category_code": 268106104, "num1": 2, "num2": 1},
                    {"category_name": "트레이닝", "category_code": 268106107, "num1": 2, "num2": 0},
                    {"category_name": "레깅스", "category_code": 268106109, "num1": 2, "num2": 0},
                    {"category_name": "슬랙스", "category_code": 268106106, "num1": 2, "num2": 0}
                ],
            },
            {
                "category_name": "원피스",
                "category_code": 268104100,
                "category3": [
                    {"category_name": "미니 원피스", "category_code": 268104101, "num1": 4, "num2": 0},
                    {"category_name": "미디 원피스", "category_code": 268104102, "num1": 4, "num2": 0},
                    {"category_name": "롱 원피스", "category_code": 268104103, "num1": 4, "num2": 0},
                    {"category_name": "데님 원피스", "category_code": 268104104, "num1": 4, "num2": 0}
                ],
            },
            {
                "category_name": "스커트",
                "category_code": 268107100,
                "category3": [
                    {"category_name": "미니", "category_code": 268107101, "num1": 2, "num2": 0},
                    {"category_name": "미디", "category_code": 268107102, "num1": 2, "num2": 0},
                    {"category_name": "롱", "category_code": 268107103, "num1": 2, "num2": 0},
                    {"category_name": "데님", "category_code": 268107104, "num1": 2, "num2": 0}
                ],
            },
            {
                "category_name": "아우터",
                "category_code": 268102100,
                "num1": 3,
                "category3": [
                    {"category_name": "무스탕", "category_code": 268102114, "num1": 3, "num2": 0},
                    {"category_name": "바람막이", "category_code": 268102135, "num1": 3, "num2": 0},
                    {"category_name": "레더 재킷", "category_code": 268102106, "num1": 3, "num2": 0},
                    {"category_name": "재킷", "category_code": 268102104, "num1": 3, "num2": 0},
                    {"category_name": "퍼재킷", "category_code": 268102115, "num1": 3, "num2": 0},
                    {"category_name": "나일론 재킷", "category_code": 268102120, "num1": 3, "num2": 0},
                    {"category_name": "트레이닝 재킷", "category_code": 268102121, "num1": 3, "num2": 0},
                    {"category_name": "데님 재킷", "category_code": 268102107, "num1": 3, "num2": 0},
                    {"category_name": "후드 집업", "category_code": 268102110, "num1": 3, "num2": 0},
                    {"category_name": "아노락", "category_code": 268102122, "num1": 3, "num2": 0},
                    {"category_name": "점퍼", "category_code": 268102119, "num1": 3, "num2": 0},
                    {"category_name": "플리스", "category_code": 268102109, "num1": 3, "num2": 0},
                    {"category_name": "하프코트", "category_code": 268102124, "num1": 3, "num2": 0},
                    {"category_name": "숏코트", "category_code": 268102123, "num1": 3, "num2": 0},
                    {"category_name": "롱코트", "category_code": 268102125, "num1": 3, "num2": 0},
                    {"category_name": "트렌치 코트", "category_code": 268102101, "num1": 3, "num2": 0},
                    {"category_name": "롱패딩", "category_code": 268102116, "num1": 3, "num2": 0},
                    {"category_name": "경량패딩", "category_code": 268102118, "num1": 3, "num2": 0},
                    {"category_name": "숏패딩", "category_code": 268102117, "num1": 3, "num2": 0},
                    {"category_name": "베스트", "category_code": 268102112, "num1": 3, "num2": 0},
                    {"category_name": "로브", "category_code": 268102113, "num1": 3, "num2": 0},
                    {"category_name": "블루종", "category_code": 268102129, "num1": 3, "num2": 0},
                    {"category_name": "야상", "category_code": 268102128, "num1": 3, "num2": 0},
                    {"category_name": "바시티", "category_code": 268102127, "num1": 3, "num2": 0}
                ],
            },
            {
                "category_name": "니트웨어",
                "category_code": 268105100,
                "category3": [
                    {"category_name": "브이넥", "category_code": 268105107, "num1": 1, "num2": 0},
                    {"category_name": "크루넥", "category_code": 268105106, "num1": 1, "num2": 0},
                    {"category_name": "터틀넥", "category_code": 268105102, "num1": 1, "num2": 0},
                    {"category_name": "카디건", "category_code": 268105103, "num1": 3, "num2": 0},
                    {"category_name": "베스트", "category_code": 268105104, "num1": 1, "num2": 0},
                ],
            }
        ]
    },
    {
        "category_name": "여성가방",
        "category_code": 269100100,
        'gender': 'female',
        "num": 0,
        "category2": [
            {
                "category_name": "숄더백",
                "category_code": 269101100,
                "category3": [],
                "num": 0
            },
            {
                "category_name": "크로스백",
                "category_code": 269102100,
                "category3": [],
                "num": 0
            },
            {
                "category_name": "토트백",
                "category_code": 269103100,
                "category3": [],
                "num": 0
            },
            {
                "category_name": "에코,캔버스백",
                "category_code": 269105100,
                "category3": [],
                "num": 0
            },
            {
                "category_name": "백팩",
                "category_code": 269106100,
                "category3": [],
                "num": 0
            },
            {
                "category_name": "파우치",
                "category_code": 269114100,
                "category3": [],
                "num": 0
            },
            {
                "category_name": "클러치",
                "category_code": 269113100,
                "category3": [],
                "num": 0
            },
        ]
    },
    {
        "category_name": "여성신발",
        "category_code": 270100100,
        'gender': 'female',
        "category2": [
            {
                "category_name": "플랫,로퍼",
                "category_code": 270101100,
                "num": 0,
                "category3": [
                    {"category_name": "플랫", "category_code": 270101101, "num": 0},
                    {"category_name": "로퍼", "category_code": 270101102, "num": 0}
                ],
            },
            {
                "category_name": "부츠",
                "category_code": 270103100,
                "num": 0,
                "category3": [
                    {"category_name": "앵클 부츠", "category_code": 270103101, "num": 0},
                    {"category_name": "니하이 부츠", "category_code": 270103102, "num": 0},
                    { "category_name": "플랫 부츠", "category_code": 270103103, "num": 0},
                    {"category_name": "미드힐 부츠", "category_code": 270103104, "num": 0},
                    {"category_name": "하이힐 부츠", "category_code": 270103105, "num": 0},
                    {"category_name": "레인 부츠", "category_code": 270103106, "num": 0}
                ],
            },
            {
                "category_name": "샌들",
                "category_code": 270104100,
                "num": 0,
                "category3": [
                    {"category_name": "플랫", "category_code": 270104101, "num": 0},
                    {"category_name": "힐", "category_code": 270104102, "num": 0}
                ],
            },
            {
                "category_name": "펌프스",
                "category_code": 270102100,
                "num": 0,
                "category3": [
                    {"category_name": "미드힐", "category_code": 270102101, "num": 0},
                    {"category_name": "하이힐", "category_code": 270102102, "num": 0}
                ],
            },
            {
                "category_name": "슬리퍼,뮬",
                "category_code": 270105100,
                "num": 0,
                "category3": [
                    {"category_name": "슬리퍼", "category_code": 270105101, "num": 0},
                    {"category_name": "뮬", "category_code": 270105102, "num": 0},
                    {"category_name": "플립플랍", "category_code": 270105103, "num": 0}
                ],
            },
            {
                "category_name": "스니커즈",
                "category_code": 270106100,
                "num": 0,
                "category3": [
                    {"category_name": "하이탑", "category_code": 270106101, "num": 0},
                    {"category_name": "로우탑", "category_code": 270106102, "num": 0},
                    {"category_name": "슬립온", "category_code": 270106103, "num": 0},
                    {"category_name": "러닝화", "category_code": 270106104, "num": 0},
                    {"category_name": "기능성 운동화", "category_code": 270106105, "num": 0}
                ],
            },
        ],
    },
    {
        "category_name": "남성의류",
        "category_code": 272100100,
        'gender': 'male',
        "category2": [
            {
                "category_name": "아우터",
                "category_code": 272102100,
                "num": 0,
                "category3": [
                    {"category_name": "무스탕", "category_code": 272102116, "num": 0},
                    {"category_name": "플리스", "category_code": 272102114, "num": 0},
                    {"category_name": "야상", "category_code": 272102122, "num": 0},
                    {"category_name": "블루종", "category_code": 272102123, "num": 0},
                    {"category_name": "바시티", "category_code": 272102124, "num": 0},
                    {"category_name": "데님 재킷", "category_code": 272102125, "num": 0},
                    {"category_name": "퍼 재킷", "category_code": 272102126, "num": 0},
                    {"category_name": "트레이닝 재킷", "category_code": 272102127, "num": 0},
                    {"category_name": "점퍼", "category_code": 272102128, "num": 0},
                    {"category_name": "바람막이", "category_code": 272102129, "num": 0},
                    {"category_name": "아노락", "category_code": 272102130, "num": 0},
                    {"category_name": "트렌치,맥코트", "category_code": 272102102, "num": 0},
                    {"category_name": "나일론,코치 재킷", "category_code": 272102112, "num": 0},
                    {"category_name": "후드 집업", "category_code": 272102109, "num": 0},
                    {"category_name": "베스트", "category_code": 272102106, "num": 0},
                    {"category_name": "레더 재킷", "category_code": 272102111, "num": 0},
                    {"category_name": "블레이저", "category_code": 272102110, "num": 0},
                    {"category_name": "롱코트", "category_code": 272102119, "num": 0},
                    {"category_name": "숏코트", "category_code": 272102117, "num": 0},
                    {"category_name": "하프코트", "category_code": 272102118, "num": 0},
                    {"category_name": "경량패딩", "category_code": 272102105, "num": 0},
                    {"category_name": "숏패딩", "category_code": 272102104, "num": 0},
                    {"category_name": "롱패딩", "category_code": 272102103, "num": 0},
                    {"category_name": "기타 아우터", "category_code": 272102113, "num": 0}
                ]
            },
            {
                "category_name": "상의",
                "category_code": 272103100,
                "num": 0,
                "category3": [
                    {"category_name": "반소매 셔츠", "category_code": 272103105, "num": 0},
                    {"category_name": "반소매 티셔츠", "category_code": 272103101, "num": 0},
                    {"category_name": "피케,카라 티셔츠", "category_code": 272103104, "num": 0},
                    {"category_name": "슬리브리스", "category_code": 272103103, "num": 0},
                    {"category_name": "스웨트셔츠", "category_code": 272103107, "num": 0},
                    {"category_name": "후디", "category_code": 272103108, "num": 0},
                    {"category_name": "집업", "category_code": 272103109, "num": 0},
                    {"category_name": "긴소매 티셔츠", "category_code": 272103102, "num": 0},
                    {"category_name": "긴소매 셔츠", "category_code": 272103106, "num": 0}
                ]
            },
            {
                "category_name": "하의",
                "category_code": 272104100,
                "num": 0,
                "category3": [
                    {"category_name": "레깅스", "category_code": 272104110, "num": 0},
                    {"category_name": "쇼트", "category_code": 272104108, "num": 0},
                    {"category_name": "부츠컷", "category_code": 272104109, "num": 0},
                    {"category_name": "슬림 팬츠", "category_code": 272104103, "num": 0},
                    {"category_name": "스트레이트 팬츠", "category_code": 272104101, "num": 0},
                    {"category_name": "와이드 팬츠", "category_code": 272104102, "num": 0},
                    {"category_name": "데님 팬츠", "category_code": 272104104, "num": 0},
                    {"category_name": "트레이닝 팬츠", "category_code": 272104107, "num": 0},
                    {"category_name": "슬랙스", "category_code": 272104106, "num": 0}
                ]
            },
            {
                "category_name": "니트웨어",
                "category_code": 272110100,
                "num": 0,
                "category3": [
                    {"category_name": "터틀넥", "category_code": 272110103, "num": 0},
                    {"category_name": "브이넥", "category_code": 272110102, "num": 0},
                    {"category_name": "크루넥", "category_code": 272110101, "num": 0},
                    {"category_name": "폴로 셔츠", "category_code": 272110107, "num": 0},
                    {"category_name": "카디건", "category_code": 272110104, "num": 0},
                    {"category_name": "베스트", "category_code": 272110105, "num": 0},
                    {"category_name": "집업", "category_code": 272110106, "num": 0}
                ]
            }
        ]
    },
    {
        "category_name": "남성가방",
        "category_code": 273100100,
        'gender': 'male',
        "category2": [
            {
                "category_name": "토트백",
                "category_code": 273103100,
                "category3": [],
            },
            {
                "category_name": "웨이스트백",
                "category_code": 273102100,
                "category3": [],
            },
            {
                "category_name": "크로스백",
                "category_code": 273101100,
                "category3": [],
            },
            {
                "category_name": "백팩",
                "category_code": 273104100,
                "category3": [],
            },
            {
                "category_name": "숄더백",
                "category_code": 273105100,
                "category3": [],
            },
            {
                "category_name": "랩탑백",
                "category_code": 273106100,
                "category3": [],
            },
            {
                "category_name": "에코,캔버스백",
                "category_code": 273107100,
                "category3": [],
            },
            {
                "category_name": "클러치",
                "category_code": 273115100,
                "category3": [],
            },
            {
                "category_name": "파우치",
                "category_code": 273116100,
                "category3": [],
            },
            {
                "category_name": "기타 가방",
                "category_code": 273110100,
                "category3": [],
            },
            {
                "category_name": "가방 액세서리",
                "category_code": 273111100,
                "category3": [],
            }
        ],
    },
    {
        "category_name": "남성신발",
        "category_code": 274100100,
        "category2": [
            {
                "category_name": "스니커즈",
                "category_code": 274101100,
                "category3": [
                    {"category_name": "하이탑", "category_code": 274101101, "num": 0,},
                    {"category_name": "로우탑", "category_code": 274101102, "num": 0},
                    {"category_name": "슬립온", "category_code": 274101103, "num": 0},
                    {"category_name": "러닝화", "category_code": 274101104, "num": 0},
                    {"category_name": "기능성 운동화", "category_code": 274101105, "num": 0}
                ],
            },
            {
                "category_name": "로퍼",
                "category_code": 274102100,
                "category3": [
                    {"category_name": "페니 로퍼", "category_code": 274102101, "num": 0},
                    {"category_name": "플레인 로퍼", "category_code": 274102102, "num": 0},
                    {"category_name": "태슬 로퍼", "category_code": 274102103, "num": 0}
                ],
            },
            {
                "category_name": "구두",
                "category_code": 274103100,
                "category3": [
                    {"category_name": "더비", "category_code": 274103102, "num": 0},
                    {"category_name": "레이스업", "category_code": 274103101, "num": 0}
                ],
            },
            {
                "category_name": "부츠",
                "category_code": 274104100,
                "category3": [
                    {"category_name": "첼시 부츠", "category_code": 274104101, "num": 0,},
                    {"category_name": "데저트 부츠", "category_code": 274104102, "num": 0,},
                    {"category_name": "미들 부츠", "category_code": 274104103, "num": 0,},
                    {"category_name": "레인 부츠", "category_code": 274104104, "num": 0,}
                ],
            },
            {
                "category_name": "샌들",
                "category_code": 274105100,
                "category3": [
                    {"category_name": "슬리퍼", "category_code": 274105101, "num": 0,},
                    {"category_name": "플립플랍", "category_code": 274105102, "num": 0},
                    {"category_name": "뮬", "category_code": 274105103, "num": 0},
                    {"category_name": "샌들", "category_code": 274105104, "num": 0}
                ],
            },
        ],
    }
]

 
# # 저장
# with open("29cm_category.pkl","wb") as f: # wb : 바이트 형식으로 쓰기
#     pickle.dump(list_1, f) #(저장하고자 하는 객체, 파일)
 
# # 호출
# with open("29cm_category.pkl","rb") as f: # rb : 바이트 형식으로 읽어오기
#     data = pickle.load(f) # (파일)
    
# print(data)
# Out:
# Data with key 1 does not exist.

# %%
def get_twentyninecm_category(category1_code):
    url = 'https://cache.29cm.co.kr/item/category/'
    params = {
        'category1_code': category1_code,
        'sortBy': 'VISIT_COUNT'
    }
    response = requests.get(url, params=params)

    try:
        response.raise_for_status()
        print("Request was successful!")
    except requests.exceptions.HTTPError as err:
        print(f"HTTP Error: {err}")

    results = response.json()
    return results['results']
272103100

get_twentyninecm_category(268100100)
# Out:
# Request was successful!
# [{'category': {'category_name': '여성의류',
#    'category_code': 268100100,
#    'category2': [{'category_name': '상의',
#      'category_code': 268103100,
#      'category3': [{'category_name': '긴소매 티셔츠',
#        'category_code': 268103102,
#        'count': 0},
#       {'category_name': '스웨트셔츠', 'category_code': 268103104, 'count': 0},
#       {'category_name': '블라우스', 'category_code': 268103107, 'count': 0},
#       {'category_name': '셔츠', 'category_code': 268103106, 'count': 0},
#       {'category_name': '반소매 티셔츠', 'category_code': 268103101, 'count': 0},
#       {'category_name': '후디', 'category_code': 268103105, 'count': 0},
#       {'category_name': '슬리브리스', 'category_code': 268103103, 'count': 0}],
#      'count': 0},
#     {'category_name': '아우터',
#      'category_code': 268102100,
#      'category3': [{'category_name': '재킷',
#        'category_code': 268102104,
#        'count': 0},
# ...
